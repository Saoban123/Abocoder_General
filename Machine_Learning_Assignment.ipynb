# %%
import pandas as pd
Nigeria_weather = pd.DataFrame({
    'city' : ['Lagos', 'Ogun', 'Osun', 'Oyo', 'Ondo', 'Abuja', 'Kaduna', 'Kano', 'Ekiti', 'Edo'],
    'humidity' : [70, 40, 90, 80, 20, 46, 79, 42, 65, 50],
    'temperature' : [23, 35, 73, 90, 20, 34, 85, 72, 57, 49]
})
Nigeria_weather
# Out:
#      city  humidity  temperature
# 0   Lagos        70           23
# 1    Ogun        40           35
# 2    Osun        90           73
# 3     Oyo        80           90
# 4    Ondo        20           20
# 5   Abuja        46           34
# 6  Kaduna        79           85
# 7    Kano        42           72
# 8   Ekiti        65           57
# 9     Edo        50           49

# %%
import pandas as pd
India_weather = pd.DataFrame({
    'city' : ['Mumbai', 'Delhi', 'Banglore', 'Kolkata', 'Bengaluru', 'Chennai', 'Pune', 'Ahmedadad', 'Hyderabad', 'Surat'],
    'humidity' : [80, 60, 78, 91, 39, 47, 49, 81, 56, 66],
    'temperature' : [32, 45, 30, 48, 39, 87, 29, 89, 30, 64]
})
India_weather
# Out:
#         city  humidity  temperature
# 0     Mumbai        80           32
# 1      Delhi        60           45
# 2   Banglore        78           30
# 3    Kolkata        91           48
# 4  Bengaluru        39           39
# 5    Chennai        47           87
# 6       Pune        49           29
# 7  Ahmedadad        81           89
# 8  Hyderabad        56           30
# 9      Surat        66           64

# %%
US_weather = pd.DataFrame({
    'city' : ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose'],
    'humidity' : [23, 46, 55, 78, 90, 24, 67, 39, 78, 34],
    'temperature' : [89, 78, 34, 60, 88, 67, 34, 14, 10, 86]
})
US_weather
# Out:
#            city  humidity  temperature
# 0      New York        23           89
# 1   Los Angeles        46           78
# 2       Chicago        55           34
# 3       Houston        78           60
# 4       Phoenix        90           88
# 5  Philadelphia        24           67
# 6   San Antonio        67           34
# 7     San Diego        39           14
# 8        Dallas        78           10
# 9      San Jose        34           86

# %%
Korea_weather = pd.DataFrame({
    'city' : ['Seoul', 'Busan', 'Incheon', 'Daegu', 'Daejeon', 'Gwangju', 'Suwan', 'Ulsan', 'Changwon', 'Goyang'],
    'humidity' : [34, 64, 58, 76, 67, 88, 25, 16, 80, 91],
    'temperature' : [55, 66, 87, 92, 34, 59, 78, 20, 59, 49]
})
Korea_weather
# Out:
#        city  humidity  temperature
# 0     Seoul        34           55
# 1     Busan        64           66
# 2   Incheon        58           87
# 3     Daegu        76           92
# 4   Daejeon        67           34
# 5   Gwangju        88           59
# 6     Suwan        25           78
# 7     Ulsan        16           20
# 8  Changwon        80           59
# 9    Goyang        91           49

# %%
France_weather = pd.DataFrame({
    'city' : ['Colmar', 'Haguenau', 'Mulhouse', 'Ribeauville', 'Strasbourg', 'Agen', 'Bayonne', 'Bergerac', 'Dax', 'Pau'],
    'humidity' : [89, 64, 45, 89, 76, 34, 33, 80, 38, 32],
    'temperature' : [46, 89, 67, 46, 91, 34, 36, 67, 89, 43]
})
France_weather
# Out:
#           city  humidity  temperature
# 0       Colmar        89           46
# 1     Haguenau        64           89
# 2     Mulhouse        45           67
# 3  Ribeauville        89           46
# 4   Strasbourg        76           91
# 5         Agen        34           34
# 6      Bayonne        33           36
# 7     Bergerac        80           67
# 8          Dax        38           89
# 9          Pau        32           43

# %%
Chinese_weather = pd.DataFrame({
    'city' : ['Hong Kong', 'Macau', 'Beijing', 'Chongqing', 'Shanghai','Tianjin', 'Anqing', 'Bengbu', 'Chaohu', 'Fuding'],
    'humidity' : [78, 36, 89, 27, 87, 76, 88, 34, 67, 78],
    'temperature' : [77, 88, 13, 76, 92, 44, 75, 81, 76, 25]
})
Chinese_weather
# Out:
#         city  humidity  temperature
# 0  Hong Kong        78           77
# 1      Macau        36           88
# 2    Beijing        89           13
# 3  Chongqing        27           76
# 4   Shanghai        87           92
# 5    Tianjin        76           44
# 6     Anqing        88           75
# 7     Bengbu        34           81
# 8     Chaohu        67           76
# 9     Fuding        78           25

# %%
Canada_weather = pd.DataFrame({
    'city' : ['Banff', 'Brooks', 'Calgary', 'Jasper', 'Red Deer', 'Saint Albert', 'Hope', 'Langley', 'White rock', 'Gander'],
    'humidity' : [77, 98, 34, 56, 34, 78, 23, 47, 81, 14],
    'temperature' : [66, 18, 37, 49, 64, 72, 50, 76, 85, 77]
})
Canada_weather
# Out:
#            city  humidity  temperature
# 0         Banff        77           66
# 1        Brooks        98           18
# 2       Calgary        34           37
# 3        Jasper        56           49
# 4      Red Deer        34           64
# 5  Saint Albert        78           72
# 6          Hope        23           50
# 7       Langley        47           76
# 8    White rock        81           85
# 9        Gander        14           77

# %%
Ghana_weather = pd.DataFrame({
    'city' : ['Accra', 'Kumasi', 'Tamale', 'Sunyani', 'Koforidua', 'Tema', 'Wa', 'Ho', 'Dome', 'Ejura'],
    'humidity' : [77, 98, 66, 53, 33, 87, 13, 98, 43, 33],
    'temperature' : [36, 73, 81, 99, 38, 49, 29, 18, 39, 46]
})
Ghana_weather
# Out:
#         city  humidity  temperature
# 0      Accra        77           36
# 1     Kumasi        98           73
# 2     Tamale        66           81
# 3    Sunyani        53           99
# 4  Koforidua        33           38
# 5       Tema        87           49
# 6         Wa        13           29
# 7         Ho        98           18
# 8       Dome        43           39
# 9      Ejura        33           46

# %%
Egypt_weather = pd.DataFrame({
    'city' : ['Cairo', 'Alexandria', 'Giza', 'Port Said', 'Suez', 'Luxor', 'Tanta', 'Asyut', 'Ismailia', 'Zagazig'],
    'humidity' : [14, 37, 87, 34, 66, 60, 80, 20, 77, 84],
    'temperature' : [23, 46, 87, 12, 98, 46, 59, 55, 88, 34]
})
Egypt_weather
# Out:
#          city  humidity  temperature
# 0       Cairo        14           23
# 1  Alexandria        37           46
# 2        Giza        87           87
# 3   Port Said        34           12
# 4        Suez        66           98
# 5       Luxor        60           46
# 6       Tanta        80           59
# 7       Asyut        20           55
# 8    Ismailia        77           88
# 9     Zagazig        84           34

# %%
Florida_weather = pd.DataFrame({
    'city' : ['Maimi', 'Tampa', 'Orlando', 'Hollywood', 'Clearwater', 'Brando', 'Lakeland', 'Davie', 'Alafaya', 'Largo'],
    'humidity' : [47, 81, 66, 50, 33, 81, 43, 38, 13, 63],
    'temperature' : [60, 71, 41, 33, 47, 77, 22, 23, 88, 60]
})
Florida_weather
# Out:
#          city  humidity  temperature
# 0       Maimi        47           60
# 1       Tampa        81           71
# 2     Orlando        66           41
# 3   Hollywood        50           33
# 4  Clearwater        33           47
# 5      Brando        81           77
# 6    Lakeland        43           22
# 7       Davie        38           23
# 8     Alafaya        13           88
# 9       Largo        63           60

# %%
Saudi_Arabia_weather = pd.DataFrame({
    'city' : ['Abha', 'Badr', 'Bareq', 'Duba', 'Gerrha', 'Haql', 'Hofuf', 'Jalajil', 'Jizan', 'jubail'],
    'humidity' : [33, 99, 43, 52, 22, 31, 13, 88, 55, 30],
    'temperature' : [14, 66, 16, 79, 32, 40, 33, 26, 77, 26]
})
Saudi_Arabia_weather
# Out:
#       city  humidity  temperature
# 0     Abha        33           14
# 1     Badr        99           66
# 2    Bareq        43           16
# 3     Duba        52           79
# 4   Gerrha        22           32
# 5     Haql        31           40
# 6    Hofuf        13           33
# 7  Jalajil        88           26
# 8    Jizan        55           77
# 9   jubail        30           26

# %%
Germany_weather = pd.DataFrame({
    'city' : ['Berin', 'Hamburg', 'Essen', 'Bochum', 'Munster', 'Augsburg', 'Kiel', 'Lubeck', 'Rostock', 'Hamm'],
    'humidity' : [11, 10, 16, 77, 88, 22, 92, 88, 39, 19],
    'temperature' : [55, 34, 66, 59, 62, 47, 30, 29, 74, 39]
})
Germany_weather
# Out:
#        city  humidity  temperature
# 0     Berin        11           55
# 1   Hamburg        10           34
# 2     Essen        16           66
# 3    Bochum        77           59
# 4   Munster        88           62
# 5  Augsburg        22           47
# 6      Kiel        92           30
# 7    Lubeck        88           29
# 8   Rostock        39           74
# 9      Hamm        19           39

# %%
BurkinaFaso_weather = pd.DataFrame({
    'city' : ['Ouagadougou', 'Bobo Diolasso', 'Banfora', 'Koudougou', 'Ouahigouya', 'Kaya', 'Fada ngourma', 'Tenkodogo', 'Hounde', 'Dedougou'],
    'humidity' : [51, 15, 86, 71, 28, 74, 66, 29, 88, 23],
    'temperature' : [11, 44, 56, 46, 32, 42, 39, 26, 84, 69]
})
BurkinaFaso_weather
# Out:
#             city  humidity  temperature
# 0    Ouagadougou        51           11
# 1  Bobo Diolasso        15           44
# 2        Banfora        86           56
# 3      Koudougou        71           46
# 4     Ouahigouya        28           32
# 5           Kaya        74           42
# 6   Fada ngourma        66           39
# 7      Tenkodogo        29           26
# 8         Hounde        88           84
# 9       Dedougou        23           69

# %%
Chad_weather = pd.DataFrame({
    'city' : ['Kelo', 'Pala', 'Mongo', 'Bongor','Sarh', 'NDjamena', 'Moundou', 'Abeche', 'Koumra', 'Am Timan'],
    'humidity' : [66, 99, 23, 77, 68, 88, 26, 29, 18, 44],
    'temperature' : [21, 35, 76, 45, 48, 19, 49, 76, 24, 73]
})
Chad_weather
# Out:
#        city  humidity  temperature
# 0      Kelo        66           21
# 1      Pala        99           35
# 2     Mongo        23           76
# 3    Bongor        77           45
# 4      Sarh        68           48
# 5  NDjamena        88           19
# 6   Moundou        26           49
# 7    Abeche        29           76
# 8    Koumra        18           24
# 9  Am Timan        44           73

# %%
Algeria_weather = pd.DataFrame({
    'city' : ['Algiers', 'Oran', 'Batna', 'Setif', 'Biska', 'Tiaret', 'Chlef', 'Blida', 'Bschar', 'Jijel'],
    'humidity' : [22, 87, 36, 56, 23, 67, 44, 76, 24, 33],
    'temperature' : [30, 14, 51, 23, 77, 97, 32, 73, 98, 30]
})
Algeria_weather
# Out:
#       city  humidity  temperature
# 0  Algiers        22           30
# 1     Oran        87           14
# 2    Batna        36           51
# 3    Setif        56           23
# 4    Biska        23           77
# 5   Tiaret        67           97
# 6    Chlef        44           32
# 7    Blida        76           73
# 8   Bschar        24           98
# 9    Jijel        33           30

# %%
con1 = pd.concat([Nigeria_weather, India_weather, US_weather, Korea_weather, France_weather, Chinese_weather, Canada_weather, Ghana_weather, Egypt_weather, Florida_weather, Saudi_Arabia_weather, Germany_weather, BurkinaFaso_weather, Chad_weather, Algeria_weather])
pd.set_option('display.max_rows', con1.shape[0] + 1)
con1
# Out:
#             city  humidity  temperature
# 0          Lagos        70           23
# 1           Ogun        40           35
# 2           Osun        90           73
# 3            Oyo        80           90
# 4           Ondo        20           20
# 5          Abuja        46           34
# 6         Kaduna        79           85
# 7           Kano        42           72
# 8          Ekiti        65           57
# 9            Edo        50           49
# 0         Mumbai        80           32
# 1          Delhi        60           45
# 2       Banglore        78           30
# 3        Kolkata        91           48
# 4      Bengaluru        39           39
# 5        Chennai        47           87
# 6           Pune        49           29
# 7      Ahmedadad        81           89
# 8      Hyderabad        56           30
# 9          Surat        66           64
# 0       New York        23           89
# 1    Los Angeles        46           78
# ...

# %%
con1 = pd.concat([Nigeria_weather, India_weather, US_weather, Korea_weather, France_weather, Chinese_weather, Canada_weather, Ghana_weather, Egypt_weather, Florida_weather, Saudi_Arabia_weather, Germany_weather, BurkinaFaso_weather, Chad_weather, Algeria_weather], ignore_index = True)
pd.set_option('display.max_rows', con1.shape[0] + 1)
con1
# Out:
#               city  humidity  temperature
# 0            Lagos        70           23
# 1             Ogun        40           35
# 2             Osun        90           73
# 3              Oyo        80           90
# 4             Ondo        20           20
# 5            Abuja        46           34
# 6           Kaduna        79           85
# 7             Kano        42           72
# 8            Ekiti        65           57
# 9              Edo        50           49
# 10          Mumbai        80           32
# 11           Delhi        60           45
# 12        Banglore        78           30
# 13         Kolkata        91           48
# 14       Bengaluru        39           39
# 15         Chennai        47           87
# 16            Pune        49           29
# 17       Ahmedadad        81           89
# 18       Hyderabad        56           30
# 19           Surat        66           64
# 20        New York        23           89
# ...

# %%
df = pd.concat([Nigeria_weather, India_weather, US_weather, Korea_weather, France_weather, Chinese_weather, Canada_weather, Ghana_weather, Egypt_weather, Florida_weather, Saudi_Arabia_weather, Germany_weather, BurkinaFaso_weather, Chad_weather, Algeria_weather], keys = ['Nigeria', 'India', 'USA', 'Korea', 'France', 'Chinese', 'Canada','Ghana', 'Egypt', 'Florida', 'Saudi Arabia', 'Germany', 'Burkina Faso', 'Chad', 'Algeria'])
pd.set_option('display.max_rows', df.shape[0] + 1)
df
# Out:
#                          city  humidity  temperature
# Nigeria      0          Lagos        70           23
#              1           Ogun        40           35
#              2           Osun        90           73
#              3            Oyo        80           90
#              4           Ondo        20           20
#              5          Abuja        46           34
#              6         Kaduna        79           85
#              7           Kano        42           72
#              8          Ekiti        65           57
#              9            Edo        50           49
# India        0         Mumbai        80           32
#              1          Delhi        60           45
#              2       Banglore        78           30
#              3        Kolkata        91           48
#              4      Bengaluru        39           39
#              5        Chennai        47           87
#              6           Pune        49           29
# ...

# %%
s = pd.Series(['Spring', 'Autumn', 'Winter', 'Summer', 'Autumn', 'Autumn','Summer','Spring', 'Winter', 'Autumn'], name = 'Season')
s
# Out:
# 0    Spring
# 1    Autumn
# 2    Winter
# 3    Summer
# 4    Autumn
# 5    Autumn
# 6    Summer
# 7    Spring
# 8    Winter
# 9    Autumn
# Name: Season, dtype: object

# %%
p = pd.concat([con1, s], axis = 1)
p
# Out:
#               city  humidity  temperature  Season
# 0            Lagos        70           23  Spring
# 1             Ogun        40           35  Autumn
# 2             Osun        90           73  Winter
# 3              Oyo        80           90  Summer
# 4             Ondo        20           20  Autumn
# 5            Abuja        46           34  Autumn
# 6           Kaduna        79           85  Summer
# 7             Kano        42           72  Spring
# 8            Ekiti        65           57  Winter
# 9              Edo        50           49  Autumn
# 10          Mumbai        80           32     NaN
# 11           Delhi        60           45     NaN
# 12        Banglore        78           30     NaN
# 13         Kolkata        91           48     NaN
# 14       Bengaluru        39           39     NaN
# 15         Chennai        47           87     NaN
# 16            Pune        49           29     NaN
# 17       Ahmedadad        81           89     NaN
# ...

# %%
mode = p.Season.mode()
mode
# Out:
# 0    Autumn
# dtype: object

# %%
p.fillna(mode.iloc[0]) #, inplace = True)
# Out:
#               city  humidity  temperature  Season
# 0            Lagos        70           23  Spring
# 1             Ogun        40           35  Autumn
# 2             Osun        90           73  Winter
# 3              Oyo        80           90  Summer
# 4             Ondo        20           20  Autumn
# 5            Abuja        46           34  Autumn
# 6           Kaduna        79           85  Summer
# 7             Kano        42           72  Spring
# 8            Ekiti        65           57  Winter
# 9              Edo        50           49  Autumn
# 10          Mumbai        80           32  Autumn
# 11           Delhi        60           45  Autumn
# 12        Banglore        78           30  Autumn
# 13         Kolkata        91           48  Autumn
# 14       Bengaluru        39           39  Autumn
# 15         Chennai        47           87  Autumn
# 16            Pune        49           29  Autumn
# 17       Ahmedadad        81           89  Autumn
# ...
