# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
df=pd.read_csv('HR_comma_sep.csv')
#pd.set_option('display.max_rows', df.shape[0] + 1)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# 2                       272                   4              0     1
# 3                       223                   5              0     1
# 4                       159                   3              0     1
# ...                     ...                 ...            ...   ...
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department  salary
# 0                          0      sales     low
# 1                          0      sales  medium
# 2                          0      sales  medium
# 3                          0      sales     low
# 4                          0      sales     low
# ...                      ...        ...     ...
# 14994                      0    support     low
# 14995                      0    support     low
# 14996                      0    support     low
# 14997                      0    support     low
# 14998                      0    support     low
#
# [14999 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['last_evaluation', 'number_project', 'time_spend_company', 'Department', 'salary', 'left'], axis = 'columns')
X
# Out:
#        satisfaction_level  average_montly_hours  Work_accident  \
# 0                    0.38                   157              0
# 1                    0.80                   262              0
# 2                    0.11                   272              0
# 3                    0.72                   223              0
# 4                    0.37                   159              0
# ...                   ...                   ...            ...
# 14994                0.40                   151              0
# 14995                0.37                   160              0
# 14996                0.37                   143              0
# 14997                0.11                   280              0
# 14998                0.37                   158              0
#
#        promotion_last_5years
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 14994                      0
# 14995                      0
# 14996                      0
# 14997                      0
# 14998                      0
#
# [14999 rows x 4 columns]

# %%
y = df['left']
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
#X_train

# %%
from sklearn.tree import DecisionTreeClassifier
import time
model = DecisionTreeClassifier()
#model

start = time.time()
model.fit(X_train, y_train)
stop = time.time()

print(f'Training Time: {stop - start}s')
# Out:
# Training Time: 0.0468745231628418s

# %%
from sklearn.linear_model import LogisticRegression
logis = LogisticRegression()

start = time.time()
logis.fit(X_train, y_train)
stop = time.time()

print(f'Training Time: {stop - start}s')
# Out:
# Training Time: 0.16598749160766602s

# %%
from sklearn.neighbors import KNeighborsClassifier

classifier = KNeighborsClassifier(n_neighbors = 5)

start = time.time()
classifier.fit(X_train, y_train)
stop = time.time()

print(f'Training Time: {stop - start}s')
# Out:
# Training Time: 0.04931759834289551s

# %%
from sklearn.ensemble import RandomForestClassifier

random = RandomForestClassifier(n_estimators = 100)

start = time.time()
random.fit(X_train, y_train)
stop = time.time()

print(f'Training Time: {stop - start}s')
# Out:
# Training Time: 1.92433500289917s

# %%
from sklearn.svm import SVC

sv = SVC(kernel = 'linear')

start = time.time()
sv.fit(X_train, y_train)
stop = time.time()

print(f'Training Time: {stop - start}s')
# Out:
# Training Time: 303.56649112701416s
